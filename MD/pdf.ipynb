# %%
import requests
import os
from bs4 import BeautifulSoup
from PyPDF2 import PdfMerger
import time
import logging
import urllib.parse
import subprocess

# Configurar logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# URL de la página principal
main_url = "https://madi.nekomath.com/P5/ReduccionesPvsNP.html"

def get_page_links(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        logger.info(f"Contenido de la página: {response.text[:500]}...")  # Mostrar los primeros 500 caracteres
        soup = BeautifulSoup(response.text, 'html.parser')
        links = []
        for a in soup.find_all('a', href=True):
            href = a['href']
            logger.info(f"Enlace encontrado: {href}")
            if href.startswith(('Satisfacibilidad', 'CliqueCoverVertex', 'HamiltonTSP', '3COLOR')) or href == "ReduccionesPvsNP.html":
                full_url = urllib.parse.urljoin(url, href)
                if full_url not in links:
                    links.append(full_url)
        logger.info(f"Total de enlaces relevantes encontrados: {len(links)}")
        return links
    except requests.exceptions.RequestException as e:
        logger.error(f"Error al obtener enlaces de la página principal: {e}")
        return []

def html_to_pdf(url, output_filename):
    try:
        command = ['wkhtmltopdf', url, output_filename]
        result = subprocess.run(command, check=True, capture_output=True, text=True)
        logger.info(f"Salida de wkhtmltopdf: {result.stdout}")
        logger.info(f"PDF creado con éxito: {output_filename}")
        return True
    except subprocess.CalledProcessError as e:
        logger.error(f"Error al crear PDF {output_filename}: {e}")
        logger.error(f"Salida de error: {e.stderr}")
        return False

# Crear directorio para guardar los PDFs
if not os.path.exists("pdfs"):
    os.makedirs("pdfs")

# Obtener enlaces de la página principal
page_links = get_page_links(main_url)
logger.info(f"Enlaces obtenidos: {page_links}")

# Procesar cada página
successful_pdfs = []
for page_url in page_links:
    logger.info(f"Procesando página: {page_url}")
    
    pdf_filename = f"pdfs/{os.path.basename(page_url).replace('.html', '.pdf')}"
    if html_to_pdf(page_url, pdf_filename):
        successful_pdfs.append(pdf_filename)
    
    time.sleep(1)  # Esperar 1 segundo entre solicitudes

# Combinar PDFs
if successful_pdfs:
    merger = PdfMerger()
    for pdf in successful_pdfs:
        try:
            merger.append(pdf)
            logger.info(f"PDF agregado con éxito: {pdf}")
        except Exception as e:
            logger.error(f"Error al procesar {pdf}: {e}")

    try:
        merger.write("madi_nekomath_combined.pdf")
        merger.close()
        logger.info("PDFs combinados con éxito en 'madi_nekomath_combined.pdf'")
    except Exception as e:
        logger.error(f"Error al escribir el PDF combinado: {e}")
else:
    logger.warning("No se crearon PDFs con éxito. No se puede combinar.")

logger.info("Proceso completado. Por favor, revisa los logs para más detalles.")
# Out:
# INFO:__main__:Contenido de la página:
#
# <!DOCTYPE html>
#
#
# <html lang="es" >
#
#   <head>
#     <meta charset="utf-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" /><meta name="generator" content="Docutils 0.18.1: http://docutils.sourceforge.net/" />
#
#     <title>Clases de complejidad y P vs. NP &#8212; MatemÃ¡ticas Discretas para Ciencia de Datos</title>
#
#
#
#   <script data-cfasync="false">
#     document.documentElement.dataset.mode = localStorage.getItem("mode") || "";
#     document.documentElement.datas...
# INFO:__main__:Enlace encontrado: #main-content
# INFO:__main__:Enlace encontrado: ../intro.html
# INFO:__main__:Enlace encontrado: ../intro.html
# INFO:__main__:Enlace encontrado: BFS.html
# INFO:__main__:Enlace encontrado: AplicacionesBFS.html
# INFO:__main__:Enlace encontrado: DFS.html
# INFO:__main__:Enlace encontrado: AplicacionesDFS.html
# INFO:__main__:Enlace encontrado: ArbolPesoMin.html
# INFO:__main__:Enlace encontrado: CaminosCortos.html
# INFO:__main__:Enlace encontrado: RedesFlujos.html
# INFO:__main__:Enlace encontrado: FordFulkerson.html
# INFO:__main__:Enlace encontrado: #
# INFO:__main__:Enlace encontrado: GraficasNP.html
# INFO:__main__:Enlace encontrado: ../_sources/P5/ReduccionesPvsNP.ipynb
# INFO:__main__:Enlace encontrado: #introduccion
# INFO:__main__:Enlace encontrado: #las-clase-de-complejidad-p
# INFO:__main__:Enlace encontrado: #la-clase-de-complejidad-np
# INFO:__main__:Enlace encontrado: #reducciones-y-la-clases-np-completo-y-np-dificil
# INFO:__main__:Enlace encontrado: #el-problema-p-vs-np
# INFO:__main__:Enlace encontrado: #tarea-moral
# INFO:__main__:Enlace encontrado: #clases-de-complejidad-y-p-vs-np
# INFO:__main__:Enlace encontrado: #introduccion
# INFO:__main__:Enlace encontrado: #las-clase-de-complejidad-p
# INFO:__main__:Enlace encontrado: #la-clase-de-complejidad-np
# INFO:__main__:Enlace encontrado: #reducciones-y-la-clases-np-completo-y-np-dificil
# INFO:__main__:Enlace encontrado: #el-problema-p-vs-np
# INFO:__main__:Enlace encontrado: #tarea-moral
# INFO:__main__:Enlace encontrado: https://www.youtube.com/watch?v=RqtQPcEU9U4&list=PLsHfADbz5gM5UJaWDTXaWSHQ1MrGvbOuq
# INFO:__main__:Enlace encontrado: FordFulkerson.html
# INFO:__main__:Enlace encontrado: GraficasNP.html
# INFO:__main__:Enlace encontrado: #introduccion
# INFO:__main__:Enlace encontrado: #las-clase-de-complejidad-p
# INFO:__main__:Enlace encontrado: #la-clase-de-complejidad-np
# INFO:__main__:Enlace encontrado: #reducciones-y-la-clases-np-completo-y-np-dificil
# INFO:__main__:Enlace encontrado: #el-problema-p-vs-np
# INFO:__main__:Enlace encontrado: #tarea-moral
# INFO:__main__:Total de enlaces relevantes encontrados: 0
# INFO:__main__:Enlaces obtenidos: []
# WARNING:__main__:No se crearon PDFs con éxito. No se puede combinar.
# INFO:__main__:Proceso completado. Por favor, revisa los logs para más detalles.

# %%
import requests
import os
from bs4 import BeautifulSoup
from PyPDF2 import PdfMerger
import time
import logging
import urllib.parse
import subprocess

# Configurar logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# URL de la página principal
main_url = "https://madi.nekomath.com/P5/ReduccionesPvsNP.html"

def get_page_links(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        logger.info(f"Contenido de la página: {response.text[:500]}...")
        soup = BeautifulSoup(response.text, 'html.parser')
        links = []
        for a in soup.find_all('a', href=True):
            href = a['href']
            logger.info(f"Enlace encontrado: {href}")
            if href.endswith('.html') and not href.startswith(('#', 'http', 'https')):
                full_url = urllib.parse.urljoin(url, href)
                if full_url not in links:
                    links.append(full_url)
        logger.info(f"Total de enlaces relevantes encontrados: {len(links)}")
        return links
    except requests.exceptions.RequestException as e:
        logger.error(f"Error al obtener enlaces de la página principal: {e}")
        return []

def html_to_pdf(url, output_filename):
    try:
        # Paso 1: Descargar el HTML
        response = requests.get(url)
        response.raise_for_status()
        html_content = response.text

        # Paso 2: Convertir HTML a LaTeX usando Pandoc
        latex_filename = output_filename.replace('.pdf', '.tex')
        pandoc_html_to_latex = ['pandoc', '-f', 'html', '-t', 'latex', '--mathjax', '-o', latex_filename]
        result = subprocess.run(pandoc_html_to_latex, input=html_content, text=True, capture_output=True, check=True)
        logger.info(f"LaTeX creado con éxito: {latex_filename}")

        # Paso 3: Convertir LaTeX a PDF
        pdflatex_command = ['pdflatex', '-interaction=nonstopmode', latex_filename]
        result = subprocess.run(pdflatex_command, check=True, capture_output=True, text=True)
        logger.info(f"PDF creado con éxito: {output_filename}")

        # Limpiar archivos temporales
        for ext in ['.aux', '.log', '.out']:
            temp_file = output_filename.replace('.pdf', ext)
            if os.path.exists(temp_file):
                os.remove(temp_file)

        return True
    except (subprocess.CalledProcessError, requests.exceptions.RequestException) as e:
        logger.error(f"Error al crear PDF {output_filename}: {e}")
        return False

# Crear directorio para guardar los PDFs
if not os.path.exists("pdfs"):
    os.makedirs("pdfs")

# Obtener enlaces de la página principal
page_links = get_page_links(main_url)
logger.info(f"Enlaces obtenidos: {page_links}")

# Procesar cada página
successful_pdfs = []
for page_url in page_links:
    logger.info(f"Procesando página: {page_url}")
    
    pdf_filename = f"pdfs/{os.path.basename(page_url).replace('.html', '.pdf')}"
    if html_to_pdf(page_url, pdf_filename):
        successful_pdfs.append(pdf_filename)
    
    time.sleep(1)  # Esperar 1 segundo entre solicitudes

# Combinar PDFs
if successful_pdfs:
    merger = PdfMerger()
    for pdf in successful_pdfs:
        try:
            merger.append(pdf)
            logger.info(f"PDF agregado con éxito: {pdf}")
        except Exception as e:
            logger.error(f"Error al procesar {pdf}: {e}")

    try:
        merger.write("madi_nekomath_combined.pdf")
        merger.close()
        logger.info("PDFs combinados con éxito en 'madi_nekomath_combined.pdf'")
    except Exception as e:
        logger.error(f"Error al escribir el PDF combinado: {e}")
else:
    logger.warning("No se crearon PDFs con éxito. No se puede combinar.")

logger.info("Proceso completado. Por favor, revisa los logs para más detalles.")
# Out:
# INFO:__main__:Contenido de la página:
#
# <!DOCTYPE html>
#
#
# <html lang="es" >
#
#   <head>
#     <meta charset="utf-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" /><meta name="generator" content="Docutils 0.18.1: http://docutils.sourceforge.net/" />
#
#     <title>Clases de complejidad y P vs. NP &#8212; MatemÃ¡ticas Discretas para Ciencia de Datos</title>
#
#
#
#   <script data-cfasync="false">
#     document.documentElement.dataset.mode = localStorage.getItem("mode") || "";
#     document.documentElement.datas...
# INFO:__main__:Enlace encontrado: #main-content
# INFO:__main__:Enlace encontrado: ../intro.html
# INFO:__main__:Enlace encontrado: ../intro.html
# INFO:__main__:Enlace encontrado: ../P1/IntroCombinatoria.html
# INFO:__main__:Enlace encontrado: ../P1/BuscarPatron.html
# INFO:__main__:Enlace encontrado: ../P1/Casillas.html
# INFO:__main__:Enlace encontrado: DFS.html
# INFO:__main__:Enlace encontrado: AplicacionesDFS.html
# INFO:__main__:Enlace encontrado: ArbolPesoMin.html
# INFO:__main__:Enlace encontrado: CaminosCortos.html
# INFO:__main__:Enlace encontrado: RedesFlujos.html
# INFO:__main__:Enlace encontrado: FordFulkerson.html
# INFO:__main__:Enlace encontrado: #
# INFO:__main__:Enlace encontrado: GraficasNP.html
# INFO:__main__:Enlace encontrado: ../_sources/P5/ReduccionesPvsNP.ipynb
# INFO:__main__:Enlace encontrado: #introduccion
# INFO:__main__:Enlace encontrado: #las-clase-de-complejidad-p
# INFO:__main__:Enlace encontrado: #la-clase-de-complejidad-np
# INFO:__main__:Enlace encontrado: #reducciones-y-la-clases-np-completo-y-np-dificil
# INFO:__main__:Enlace encontrado: #el-problema-p-vs-np
# INFO:__main__:Enlace encontrado: #tarea-moral
# INFO:__main__:Enlace encontrado: #clases-de-complejidad-y-p-vs-np
# INFO:__main__:Enlace encontrado: #introduccion
# INFO:__main__:Enlace encontrado: #las-clase-de-complejidad-p
# INFO:__main__:Enlace encontrado: #la-clase-de-complejidad-np
# INFO:__main__:Enlace encontrado: #reducciones-y-la-clases-np-completo-y-np-dificil
# INFO:__main__:Enlace encontrado: #el-problema-p-vs-np
# INFO:__main__:Enlace encontrado: #tarea-moral
# INFO:__main__:Enlace encontrado: https://www.youtube.com/watch?v=RqtQPcEU9U4&list=PLsHfADbz5gM5UJaWDTXaWSHQ1MrGvbOuq
# INFO:__main__:Enlace encontrado: FordFulkerson.html
# INFO:__main__:Enlace encontrado: GraficasNP.html
# INFO:__main__:Enlace encontrado: #introduccion
# INFO:__main__:Enlace encontrado: #las-clase-de-complejidad-p
# INFO:__main__:Enlace encontrado: #la-clase-de-complejidad-np
# INFO:__main__:Enlace encontrado: #reducciones-y-la-clases-np-completo-y-np-dificil
# INFO:__main__:Enlace encontrado: #el-problema-p-vs-np
# INFO:__main__:Enlace encontrado: #tarea-moral
# INFO:__main__:Total de enlaces relevantes encontrados: 57
# INFO:__main__:Enlaces obtenidos: ['https://madi.nekomath.com/intro.html', 'https://madi.nekomath.com/P1/IntroCombinatoria.html', 'https://madi.nekomath.com/P1/BuscarPatron.html', 'https://madi.nekomath.com/P1/Casillas.html', 'https://madi.nekomath.com/P1/DobleConteo.html', 'https://madi.nekomath.com/P1/Induccion.html', 'https://madi.nekomath.com/P1/Recursion.html', 'https://madi.nekomath.com/P1/Extremo.html', 'https://madi.nekomath.com/P2/IntroGraficas.html', 'https://madi.nekomath.com/P2/GraficasGrados.html', 'https://madi.nekomath.com/P2/Caminos.html', 'https://madi.nekomath.com/P2/Ciclos.html', 'https://madi.nekomath.com/P2/Recorrer.html', 'https://madi.nekomath.com/P2/Arboles.html', 'https://madi.nekomath.com/P2/Bipartitas.html', 'https://madi.nekomath.com/P2/EmparejamientosHall.html', 'https://madi.nekomath.com/P2/Independientes.html', 'https://madi.nekomath.com/P2/Ramsey.html', 'https://madi.nekomath.com/P2/Completas.
html
# INFO:__main__:Salida de wkhtmltopdf:
# INFO:__main__:PDF creado con éxito: pdfs/ModeloRAM.pdf
# INFO:__main__:Procesando página: https://madi.nekomath.com/P3/NotacionO.html
# INFO:__main__:Salida de wkhtmltopdf:
# INFO:__main__:PDF creado con éxito: pdfs/NotacionO.pdf
# INFO:__main__:Procesando página: https://madi.nekomath.com/P3/PropiedadesO.html
# INFO:__main__:Salida de wkhtmltopdf:
# INFO:__main__:PDF creado con éxito: pdfs/PropiedadesO.pdf
# INFO:__main__:Procesando página: https://madi.nekomath.com/P3/EjemplosEficiencia.html
# INFO:__main__:Salida de wkhtmltopdf:
# INFO:__main__:PDF creado con éxito: pdfs/EjemplosEficiencia.pdf
# INFO:__main__:Procesando página: https://madi.nekomath.com/P3/ProblemaOrdenar.html
# INFO:__main__:Salida de wkhtmltopdf:
# INFO:__main__:PDF creado con éxito: pdfs/ProblemaOrdenar.pdf
# INFO:__main__:Procesando página: https://madi.nekomath.com/P3/OrdenarCuadraticamente.html
# INFO:__main__:Salida de wkhtmltopdf:
# INFO:__main__:PDF creado con éxito: pdfs/OrdenarCuadraticamente.pdf
# INFO:__main__:Procesando página: https://madi.nekomath.com/P3/EstructurasTipos.html
# INFO:__main__:Salida de wkhtmltopdf:
# INFO:__main__:PDF creado con éxito: pdfs/EstructurasTipos.pdf
# INFO:__main__:Procesando página: https://madi.nekomath.com/P3/DiccionariosArboles.html
# INFO:__main__:Salida de wkhtmltopdf:
# INFO:__main__:PDF creado con éxito: pdfs/DiccionariosArboles.pdf
# INFO:__main__:Procesando página: https://madi.nekomath.com/P3/OrdenarEficientemente.html
# INFO:__main__:Salida de wkhtmltopdf:
# INFO:__main__:PDF creado con éxito: pdfs/OrdenarEficientemente.pdf
# INFO:__main__:Procesando página: https://madi.nekomath.com/P3/AplicacionesOrdenar.html
# INFO:__main__:Salida de wkhtmltopdf:
# INFO:__main__:PDF creado con éxito: pdfs/AplicacionesOrdenar.pdf
# INFO:__main__:Procesando página: https://madi.nekomath.com/P4/IntroHeuristicas.html
# INFO:__main__:Salida de wkhtmltopdf:
# INFO:__main__:PDF creado con éxito: pdfs/IntroHeuristicas.pdf
# INFO:__main__:Procesando página: https://madi.nekomath.com/P4/OptimizacionDecision.html
# INFO:__main__:Salida de wkhtmltopdf:
# INFO:__main__:PDF creado con éxito: pdfs/OptimizacionDecision.pdf
# INFO:__main__:Procesando página: https://madi.nekomath.com/P4/EspacioHeuristicas.html
# INFO:__main__:Salida de wkhtmltopdf:
# INFO:__main__:PDF creado con éxito: pdfs/EspacioHeuristicas.pdf
# INFO:__main__:Procesando página: https://madi.nekomath.com/P4/ExploracionExhaustiva.html
# INFO:__main__:Salida de wkhtmltopdf:
# INFO:__main__:PDF creado con éxito: pdfs/ExploracionExhaustiva.pdf
# INFO:__main__:Procesando página: https://madi.nekomath.com/P4/Recortes.html
# INFO:__main__:Salida de wkhtmltopdf:
# INFO:__main__:PDF creado con éxito: pdfs/Recortes.pdf
# INFO:__main__:Procesando página: https://madi.nekomath.com/P4/Voraces.html
# INFO:__main__:Salida de wkhtmltopdf:
# INFO:__main__:PDF creado con éxito: pdfs/Voraces.pdf
# INFO:__main__:Procesando página: https://madi.nekomath.com/P4/DivideConquista.html
# INFO:__main__:Salida de wkhtmltopdf:
# INFO:__main__:PDF creado con éxito: pdfs/DivideConquista.pdf
# INFO:__main__:Procesando página: https://madi.nekomath.com/P4/TeoremaMaestro.html
# INFO:__main__:Salida de wkhtmltopdf:
# INFO:__main__:PDF creado con éxito: pdfs/TeoremaMaestro.pdf
# INFO:__main__:Procesando página: https://madi.nekomath.com/P4/Backtrack.html
# INFO:__main__:Salida de wkhtmltopdf:
# INFO:__main__:PDF creado con éxito: pdfs/Backtrack.pdf
# INFO:__main__:Procesando página: https://madi.nekomath.com/P4/BacktrackGraficas.html
# INFO:__main__:Salida de wkhtmltopdf:
# INFO:__main__:PDF creado con éxito: pdfs/BacktrackGraficas.pdf
# INFO:__main__:Procesando página: https://madi.nekomath.com/P4/Dinamica.html
# INFO:__main__:Salida de wkhtmltopdf:
# INFO:__main__:PDF creado con éxito: pdfs/Dinamica.pdf
# INFO:__main__:Procesando página: https://madi.nekomath.com/P4/IdeasProbabilistas.html
# INFO:__main__:Salida de wkhtmltopdf:
# INFO:__main__:PDF creado con éxito: pdfs/IdeasProbabilistas.pdf
# INFO:__main__:Procesando página: https://madi.nekomath.com/P5/IntroAlgoGraficas.html
# INFO:__main__:Salida de wkhtmltopdf:
# INFO:__main__:PDF creado con éxito: pdfs/IntroAlgoGraficas.pdf
# INFO:__main__:Procesando página: https://madi.nekomath.com/P5/ImplementacionesGraficas.html
# INFO:__main__:Salida de wkhtmltopdf:
# INFO:__main__:PDF creado con éxito: pdfs/ImplementacionesGraficas.pdf
# INFO:__main__:Procesando página: https://madi.nekomath.com/P5/NetworkX.html
# INFO:__main__:Salida de wkhtmltopdf:
# INFO:__main__:PDF creado con éxito: pdfs/NetworkX.pdf
# INFO:__main__:Procesando página: https://madi.nekomath.com/P5/BFS.html
# INFO:__main__:Salida de wkhtmltopdf:
# INFO:__main__:PDF creado con éxito: pdfs/BFS.pdf
# INFO:__main__:Procesando página: https://madi.nekomath.com/P5/AplicacionesBFS.html
# INFO:__main__:Salida de wkhtmltopdf:
# INFO:__main__:PDF creado con éxito: pdfs/AplicacionesBFS.pdf
# INFO:__main__:Procesando página: https://madi.nekomath.com/P5/DFS.html
# INFO:__main__:Salida de wkhtmltopdf:
# INFO:__main__:PDF creado con éxito: pdfs/DFS.pdf
# INFO:__main__:Procesando página: https://madi.nekomath.com/P5/AplicacionesDFS.html
# INFO:__main__:Salida de wkhtmltopdf:
# INFO:__main__:PDF creado con éxito: pdfs/AplicacionesDFS.pdf
# INFO:__main__:Procesando página: https://madi.nekomath.com/P5/ArbolPesoMin.html
# INFO:__main__:Salida de wkhtmltopdf:
# INFO:__main__:PDF creado con éxito: pdfs/ArbolPesoMin.pdf
# INFO:__main__:Procesando página: https://madi.nekomath.com/P5/CaminosCortos.html
# INFO:__main__:Salida de wkhtmltopdf:
# INFO:__main__:PDF creado con éxito: pdfs/CaminosCortos.pdf
# INFO:__main__:Procesando página: https://madi.nekomath.com/P5/RedesFlujos.html
# INFO:__main__:Salida de wkhtmltopdf:
# INFO:__main__:PDF creado con éxito: pdfs/RedesFlujos.pdf
# INFO:__main__:Procesando página: https://madi.nekomath.com/P5/FordFulkerson.html
# INFO:__main__:Salida de wkhtmltopdf:
# INFO:__main__:PDF creado con éxito: pdfs/FordFulkerson.pdf
# INFO:__main__:Procesando página: https://madi.nekomath.com/P5/GraficasNP.html
# INFO:__main__:Salida de wkhtmltopdf:
# INFO:__main__:PDF creado con éxito: pdfs/GraficasNP.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/intro.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/IntroCombinatoria.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/BuscarPatron.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/Casillas.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/DobleConteo.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/Induccion.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/Recursion.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/Extremo.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/IntroGraficas.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/GraficasGrados.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/Caminos.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/Ciclos.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/Recorrer.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/Arboles.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/Bipartitas.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/EmparejamientosHall.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/Independientes.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/Ramsey.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/Completas.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/IntroAlgoritmos.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/ProblemasAlgoritmos.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/Incorrectos.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/Correctos.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/ModeloRAM.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/NotacionO.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/PropiedadesO.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/EjemplosEficiencia.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/ProblemaOrdenar.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/OrdenarCuadraticamente.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/EstructurasTipos.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/DiccionariosArboles.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/OrdenarEficientemente.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/AplicacionesOrdenar.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/IntroHeuristicas.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/OptimizacionDecision.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/EspacioHeuristicas.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/ExploracionExhaustiva.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/Recortes.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/Voraces.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/DivideConquista.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/TeoremaMaestro.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/Backtrack.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/BacktrackGraficas.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/Dinamica.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/IdeasProbabilistas.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/IntroAlgoGraficas.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/ImplementacionesGraficas.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/NetworkX.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/BFS.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/AplicacionesBFS.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/DFS.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/AplicacionesDFS.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/ArbolPesoMin.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/CaminosCortos.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/RedesFlujos.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/FordFulkerson.pdf
# INFO:__main__:PDF agregado con éxito: pdfs/GraficasNP.pdf
# INFO:__main__:PDFs combinados con éxito en 'madi_nekomath_combined.pdf'
# INFO:__main__:Proceso completado. Por favor, revisa los logs para más detalles.

# %%
import requests
import os
from bs4 import BeautifulSoup
from PyPDF2 import PdfMerger
import time
import logging
import urllib.parse
import subprocess

# Configurar logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# URL de la página principal
main_url = "https://madi.nekomath.com/P5/ReduccionesPvsNP.html"

def get_page_links(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        logger.info(f"Contenido de la página: {response.text[:500]}...")
        soup = BeautifulSoup(response.text, 'html.parser')
        links = []
        for a in soup.find_all('a', href=True):
            href = a['href']
            logger.info(f"Enlace encontrado: {href}")
            if href.endswith('.html') and not href.startswith(('#', 'http', 'https')):
                full_url = urllib.parse.urljoin(url, href)
                if full_url not in links:
                    links.append(full_url)
        logger.info(f"Total de enlaces relevantes encontrados: {len(links)}")
        return links
    except requests.exceptions.RequestException as e:
        logger.error(f"Error al obtener enlaces de la página principal: {e}")
        return []

def html_to_pdf(url, output_filename):
    try:
        # Paso 1: Descargar el HTML
        response = requests.get(url)
        response.raise_for_status()
        html_content = response.text

        # Paso 2: Convertir HTML a LaTeX usando Pandoc
        latex_filename = output_filename.replace('.pdf', '.tex')
        pandoc_html_to_latex = ['pandoc', '-f', 'html', '-t', 'latex', '--mathjax', '-o', latex_filename]
        result = subprocess.run(pandoc_html_to_latex, input=html_content, text=True, capture_output=True, check=True)
        logger.info(f"LaTeX creado con éxito: {latex_filename}")

        # Paso 3: Convertir LaTeX a PDF
        pdflatex_command = ['pdflatex', '-interaction=nonstopmode', latex_filename]
        result = subprocess.run(pdflatex_command, check=True, capture_output=True, text=True)
        logger.info(f"PDF creado con éxito: {output_filename}")

        # Limpiar archivos temporales
        for ext in ['.aux', '.log', '.out']:
            temp_file = output_filename.replace('.pdf', ext)
            if os.path.exists(temp_file):
                os.remove(temp_file)

        return True
    except (subprocess.CalledProcessError, requests.exceptions.RequestException) as e:
        logger.error(f"Error al crear PDF {output_filename}: {e}")
        return False

# Crear directorio para guardar los PDFs
if not os.path.exists("pdfs"):
    os.makedirs("pdfs")

# Obtener enlaces de la página principal
page_links = get_page_links(main_url)
logger.info(f"Enlaces obtenidos: {page_links}")

# Procesar cada página
successful_pdfs = []
for page_url in page_links:
    logger.info(f"Procesando página: {page_url}")
    
    pdf_filename = f"pdfs/{os.path.basename(page_url).replace('.html', '.pdf')}"
    if html_to_pdf(page_url, pdf_filename):
        successful_pdfs.append(pdf_filename)
    
    time.sleep(1)  # Esperar 1 segundo entre solicitudes

# Combinar PDFs
if successful_pdfs:
    merger = PdfMerger()
    for pdf in successful_pdfs:
        try:
            merger.append(pdf)
            logger.info(f"PDF agregado con éxito: {pdf}")
        except Exception as e:
            logger.error(f"Error al procesar {pdf}: {e}")

    try:
        merger.write("madi_nekomath_combined.pdf")
        merger.close()
        logger.info("PDFs combinados con éxito en 'madi_nekomath_combined.pdf'")
    except Exception as e:
        logger.error(f"Error al escribir el PDF combinado: {e}")
else:
    logger.warning("No se crearon PDFs con éxito. No se puede combinar.")

logger.info("Proceso completado. Por favor, revisa los logs para más detalles.")
# Out:
# INFO:__main__:Contenido de la página:
#
# <!DOCTYPE html>
#
#
# <html lang="es" >
#
#   <head>
#     <meta charset="utf-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" /><meta name="generator" content="Docutils 0.18.1: http://docutils.sourceforge.net/" />
#
#     <title>Clases de complejidad y P vs. NP &#8212; MatemÃ¡ticas Discretas para Ciencia de Datos</title>
#
#
#
#   <script data-cfasync="false">
#     document.documentElement.dataset.mode = localStorage.getItem("mode") || "";
#     document.documentElement.datas...
# INFO:__main__:Enlace encontrado: #main-content
# INFO:__main__:Enlace encontrado: ../intro.html
# INFO:__main__:Enlace encontrado: ../intro.html
# INFO:__main__:Enlace encontrado: ../P1/IntroCombinatoria.html
# INFO:__main__:Enlace encontrado: ../P1/BuscarPatron.html
# INFO:__main__:Enlace encontrado: ../P1/Casillas.html
# INFO:__main__:Enlace encontrado: ../P1/DobleConteo.html
# INFO:__main__:Enlace encontrado: ../P1/Induccion.html
# INFO:__main__:Enlace encontrado: ../P1/Recursion.html
# INFO:__main__:Enlace encontrado: ../P1/Extremo.html
# INFO:__main__:Enlace encontrado: ../P2/IntroGraficas.html
# INFO:__main__:Enlace encontrado: ../P2/GraficasGrados.html
# INFO:__main__:Enlace encontrado: ../P2/Caminos.html
# INFO:__main__:Enlace encontrado: ../P2/Ciclos.html
# INFO:__main__:Enlace encontrado: ../P2/Recorrer.html
# INFO:__main__:Enlace encontrado: ../P2/Arboles.html
# INFO:__main__:Enlace encontrado: ../P2/Bipartitas.html
# INFO:__main__:Enlace encontrado: ../P2/EmparejamientosHall.html
# INFO:__main__:Enlace encontrado: ../P2/Independientes.html
# INFO:__main__:Enlace encontrado: ../P2/Ramsey.html
# INFO:__main__:Enlace encontrado: ../P2/Completas.html
# INFO:__main__:Enlace encontrado: ../P3/IntroAlgoritmos.html
# INFO:__main__:Enlace encontrado: ../P3/ProblemasAlgoritmos.html
# INFO:__main__:Enlace encontrado: ../P3/Incorrectos.html
# INFO:__main__:Enlace encontrado: ../P3/Correctos.html
# INFO:__main__:Enlace encontrado: ../P3/ModeloRAM.html
# INFO:__main__:Enlace encontrado: ../P3/NotacionO.html
# INFO:__main__:Enlace encontrado: ../P3/PropiedadesO.html
# INFO:__main__:Enlace encontrado: ../P3/EjemplosEficiencia.html
# INFO:__main__:Enlace encontrado: ../P3/ProblemaOrdenar.html
# INFO:__main__:Enlace encontrado: ../P3/OrdenarCuadraticamente.html
# INFO:__main__:Enlace encontrado: ../P3/EstructurasTipos.html
# INFO:__main__:Enlace encontrado: ../P3/DiccionariosArboles.html
# INFO:__main__:Enlace encontrado: ../P3/OrdenarEficientemente.html
# INFO:__main__:Enlace encontrado: ../P3/AplicacionesOrdenar.html
# INFO:__main__:Enlace encontrado: ../P4/IntroHeuristicas.html
# INFO:__main__:Enlace encontrado: ../P4/OptimizacionDecision.html
# INFO:__main__:Enlace encontrado: ../P4/EspacioHeuristicas.html
# INFO:__main__:Enlace encontrado: ../P4/ExploracionExhaustiva.html
# INFO:__main__:Enlace encontrado: ../P4/Recortes.html
# INFO:__main__:Enlace encontrado: ../P4/Voraces.html
# INFO:__main__:Enlace encontrado: ../P4/DivideConquista.html
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[20], line 80
#      77 logger.info(f"Procesando página: {page_url}")
#      79 pdf_filename = f"pdfs/{os.path.basename(page_url).replace('.html', '.pdf')}"
# ---> 80 if html_to_pdf(page_url, pdf_filename):
#      81     successful_pdfs.append(pdf_filename)
#      83 time.sleep(1)  # Esperar 1 segundo entre solicitudes
#
# Cell In[20], line 52, in html_to_pdf(url, output_filename)
#      50 # Paso 3: Convertir LaTeX a PDF
#      51 pdflatex_command = ['pdflatex', '-interaction=nonstopmode', latex_filename]
# ---> 52 result = subprocess.run(pdflatex_command, check=True, capture_output=True, text=True)
#      53 logger.info(f"PDF creado con éxito: {output_filename}")
#      55 # Limpiar archivos temporales
#
# File /opt/homebrew/anaconda3/envs/dataScience/lib/python3.12/subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File /opt/homebrew/anaconda3/envs/dataScience/lib/python3.12/subprocess.py:1209, in Popen.communicate(self, input, timeout)
#    1206     endtime = None
#    1208 try:
# -> 1209     stdout, stderr = self._communicate(input, endtime, timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # See the detailed comment in .wait().
#    1213     if timeout is not None:
#
# File /opt/homebrew/anaconda3/envs/dataScience/lib/python3.12/subprocess.py:2153, in Popen._communicate(self, input, endtime, orig_timeout)
#    2151 if self.text_mode:
#    2152     if stdout is not None:
# -> 2153         stdout = self._translate_newlines(stdout,
#    2154                                           self.stdout.encoding,
#    2155                                           self.stdout.errors)
#    2156     if stderr is not None:
#    2157         stderr = self._translate_newlines(stderr,
#    2158                                           self.stderr.encoding,
#    2159                                           self.stderr.errors)
#
# File /opt/homebrew/anaconda3/envs/dataScience/lib/python3.12/subprocess.py:1086, in Popen._translate_newlines(self, data, encoding, errors)
#    1085 def _translate_newlines(self, data, encoding, errors):
# -> 1086     data = data.decode(encoding, errors)
#    1087     return data.replace("\r\n", "\n").replace("\r", "\n")
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xb1 in position 43516: invalid start byte

# %%
def get_page_links(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        logger.info(f"Contenido de la página: {response.text[:500]}...")
        soup = BeautifulSoup(response.text, 'html.parser')
        links = []
        for a in soup.find_all('a', href=True):
            href = a['href']
            logger.info(f"Enlace encontrado: {href}")
            if href.endswith('.html') and not href.startswith(('#', 'http', 'https')):
                full_url = urllib.parse.urljoin(url, href)
                if full_url not in links:
                    links.append(full_url)
        logger.info(f"Total de enlaces relevantes encontrados: {len(links)}")
        return links
    except requests.exceptions.RequestException as e:
        logger.error(f"Error al obtener enlaces de la página principal: {e}")
        return []
    
def html_to_pdf(url, output_filename):
    try:
        # Paso 1: Descargar el contenido HTML
        response = requests.get(url)
        response.raise_for_status()
        html_content = response.text

        # Paso 2: Convertir HTML a LaTeX
        latex_filename = output_filename.replace('.pdf', '.tex')
        pandoc_html_to_latex = [
            'pandoc',
            '-f', 'html',
            '-t', 'latex',
            '--pdf-engine=xelatex',
            '--mathjax',
            '-V', 'geometry:margin=1in',
            '-V', 'mainfont:DejaVu Serif',
            '-V', 'monofont:DejaVu Sans Mono',
            '--standalone',
            '-o', latex_filename
        ]
        subprocess.run(pandoc_html_to_latex, input=html_content, text=True, check=True, capture_output=True)

        # Paso 3: Modificar el archivo LaTeX
        with open(latex_filename, 'r', encoding='utf-8') as file:
            latex_content = file.read()

        # Añadir paquetes y configuraciones adicionales
        latex_preamble = r"""
        \usepackage{fontspec}
        \usepackage{unicode-math}
        \setmainfont{DejaVu Serif}
        \setmonofont{DejaVu Sans Mono}
        \usepackage{amsmath}
        \usepackage{amssymb}
        \usepackage{graphicx}
        \usepackage{hyperref}
        \usepackage[spanish]{babel}
        """
        latex_content = latex_content.replace(r'\begin{document}', f'{latex_preamble}\n\\begin{{document}}')

        with open(latex_filename, 'w', encoding='utf-8') as file:
            file.write(latex_content)

        # Paso 4: Convertir LaTeX a PDF
        xelatex_command = ['xelatex', '-interaction=nonstopmode', latex_filename]
        for _ in range(2):  # Ejecutar dos veces para resolver referencias
            result = subprocess.run(xelatex_command, check=True, capture_output=True, text=True)
        
        logger.info(f"PDF creado con éxito: {output_filename}")

        # Limpiar archivos temporales
        for ext in ['.aux', '.log', '.out']:
            temp_file = output_filename.replace('.pdf', ext)
            if os.path.exists(temp_file):
                os.remove(temp_file)

        return True
    except subprocess.CalledProcessError as e:
        logger.error(f"Error en el proceso de conversión para {output_filename}: {e}")
        logger.error(f"Salida estándar: {e.stdout}")
        logger.error(f"Salida de error: {e.stderr}")
        return False
    except requests.exceptions.RequestException as e:
        logger.error(f"Error al descargar la página {url}: {e}")
        return False
    except Exception as e:
        logger.error(f"Error inesperado al crear PDF {output_filename}: {e}")
        return False

# Crear directorio para guardar los PDFs
if not os.path.exists("pdfs"):
    os.makedirs("pdfs")

# Obtener enlaces de la página principal
page_links = get_page_links(main_url)
logger.info(f"Enlaces obtenidos: {page_links}")

# Procesar cada página
successful_pdfs = []
for page_url in page_links:
    logger.info(f"Procesando página: {page_url}")
    
    pdf_filename = f"pdfs/{os.path.basename(page_url).replace('.html', '.pdf')}"
    if html_to_pdf(page_url, pdf_filename):
        successful_pdfs.append(pdf_filename)
    
    time.sleep(1)  # Esperar 1 segundo entre solicitudes

if successful_pdfs:
    merger = PdfMerger()
    for pdf in successful_pdfs:
        try:
            merger.append(pdf)
            logger.info(f"PDF agregado con éxito: {pdf}")
        except Exception as e:
            logger.error(f"Error al procesar {pdf}: {e}")

    try:
        merger.write("madi_nekomath_combined.pdf")
        merger.close()
        logger.info("PDFs combinados con éxito en 'madi_nekomath_combined.pdf'")
    except Exception as e:
        logger.error(f"Error al escribir el PDF combinado: {e}")
else:
    logger.warning("No se crearon PDFs con éxito. No se puede combinar.")

logger.info("Proceso completado. Por favor, revisa los logs para más detalles.")
# Out:
# INFO:__main__:Contenido de la página:
#
# <!DOCTYPE html>
#
#
# <html lang="es" >
#
#   <head>
#     <meta charset="utf-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" /><meta name="generator" content="Docutils 0.18.1: http://docutils.sourceforge.net/" />
#
#     <title>Clases de complejidad y P vs. NP &#8212; MatemÃ¡ticas Discretas para Ciencia de Datos</title>
#
#
#
#   <script data-cfasync="false">
#     document.documentElement.dataset.mode = localStorage.getItem("mode") || "";
#     document.documentElement.datas...
# INFO:__main__:Enlace encontrado: #main-content
# INFO:__main__:Enlace encontrado: ../intro.html
# INFO:__main__:Enlace encontrado: ../intro.html
# INFO:__main__:Enlace encontrado: ../P1/IntroCombinatoria.html
# INFO:__main__:Enlace encontrado: ../P1/BuscarPatron.html
# INFO:__main__:Enlace encontrado: ../P1/Casillas.html
# INFO:__main__:Enlace encontrado: ../P1/DobleConteo.html
# INFO:__main__:Enlace encontrado: ArbolPesoMin.html
# INFO:__main__:Enlace encontrado: CaminosCortos.html
# INFO:__main__:Enlace encontrado: RedesFlujos.html
# INFO:__main__:Enlace encontrado: FordFulkerson.html
# INFO:__main__:Enlace encontrado: #
# INFO:__main__:Enlace encontrado: GraficasNP.html
# INFO:__main__:Enlace encontrado: ../_sources/P5/ReduccionesPvsNP.ipynb
# INFO:__main__:Enlace encontrado: #introduccion
# INFO:__main__:Enlace encontrado: #las-clase-de-complejidad-p
# INFO:__main__:Enlace encontrado: #la-clase-de-complejidad-np
# INFO:__main__:Enlace encontrado: #reducciones-y-la-clases-np-completo-y-np-dificil
# INFO:__main__:Enlace encontrado: #el-problema-p-vs-np
# INFO:__main__:Enlace encontrado: #tarea-moral
# INFO:__main__:Enlace encontrado: #clases-de-complejidad-y-p-vs-np
# INFO:__main__:Enlace encontrado: #introduccion
# INFO:__main__:Enlace encontrado: #las-clase-de-complejidad-p
# INFO:__main__:Enlace encontrado: #la-clase-de-complejidad-np
# INFO:__main__:Enlace encontrado: #reducciones-y-la-clases-np-completo-y-np-dificil
# INFO:__main__:Enlace encontrado: #el-problema-p-vs-np
# INFO:__main__:Enlace encontrado: #tarea-moral
# INFO:__main__:Enlace encontrado: https://www.youtube.com/watch?v=RqtQPcEU9U4&list=PLsHfADbz5gM5UJaWDTXaWSHQ1MrGvbOuq
# INFO:__main__:Enlace encontrado: FordFulkerson.html
# INFO:__main__:Enlace encontrado: GraficasNP.html
# INFO:__main__:Enlace encontrado: #introduccion
# INFO:__main__:Enlace encontrado: #las-clase-de-complejidad-p
# INFO:__main__:Enlace encontrado: #la-clase-de-complejidad-np
# INFO:__main__:Enlace encontrado: #reducciones-y-la-clases-np-completo-y-np-dificil
# INFO:__main__:Enlace encontrado: #el-problema-p-vs-np
# INFO:__main__:Enlace encontrado: #tarea-moral
# INFO:__main__:Total de enlaces relevantes encontrados: 57
# INFO:__main__:Enlaces obtenidos: ['https://madi.nekomath.com/intro.html', 'https://madi.nekomath.com/P1/IntroCombinatoria.html', 'https://madi.nekomath.com/P1/BuscarPatron.html', 'https://madi.nekomath.com/P1/Casillas.html', 'https://madi.nekomath.com/P1/DobleConteo.html', 'https://madi.nekomath.com/P1/Induccion.html', 'https://madi.nekomath.com/P1/Recursion.html', 'https://madi.nekomath.com/P1/Extremo.html', 'https://madi.nekomath.com/P2/IntroGraficas.html', 'https://madi.nekomath.com/P2/GraficasGrados.html', 'https://madi.nekomath.com/P2/Caminos.html', 'https://madi.nekomath.com/P2/Ciclos.html', 'https://madi.nekomath.com/P2/Recorrer.html', 'https://madi.nekomath.com/P2/Arboles.html', 'https://madi.nekomath.com/P2/Bipartitas.html', 'https://madi.nekomath.com/P2/EmparejamientosHall.html', 'https://madi.nekomath.com/P2/Independientes.html', 'https://madi.nekomath.com/P2/Ramsey.html', 'https://madi.nekomath.com/P2/Completas.html', 'https://madi.nekomath.com/P3/IntroAlgoritmos.html', 'https://madi.nekomath.com/P3/ProblemasAlgoritmos.html', 'https://madi.nekomath.com/P3/Incorrectos.html', 'https://madi.nekomath.com/P3/Correctos.html', 'https://madi.nekomath.com/P3/ModeloRAM.html', 'https://madi.nekomath.com/P3/NotacionO.html', 'https://madi.nekomath.com/P3/PropiedadesO.html', 'https://madi.nekomath.com/P3/EjemplosEficiencia.html', 'https://madi.nekomath.com/P3/ProblemaOrdenar.html', 'https://madi.nekomath.com/P3/OrdenarCuadraticamente.html', 'https://madi.nekomath.com/P3/EstructurasTipos.html', 'https://madi.nekomath.com/P3/DiccionariosArboles.html', 'https://madi.nekomath.com/P3/OrdenarEficientemente.html', 'https://madi.nekomath.com/P3/AplicacionesOrdenar.html', 'https://madi.nekomath.com/P4/IntroHeuristicas.html', 'https://madi.nekomath.com/P4/OptimizacionDecision.html', 'https://madi.nekomath.com/P4/EspacioHeuristicas.html', 'https://madi.nekomath.com/P4/ExploracionExhaustiva.html', 'https://madi.nekomath.com/P4/Recortes.html', 'https://madi.nekomath.com/P4/Voraces.html', 'https://madi.nekomath.com/P4/DivideConquista.html', 'https://madi.nekomath.com/P4/TeoremaMaestro.html', 'https://madi.nekomath.com/P4/Backtrack.html', 'https://madi.nekomath.com/P4/BacktrackGraficas.html', 'https://madi.nekomath.com/P4/Dinamica.html', 'https://madi.nekomath.com/P4/IdeasProbabilistas.html', 'https://madi.nekomath.com/P5/IntroAlgoGraficas.html', 'https://madi.nekomath.com/P5/ImplementacionesGraficas.html', 'https://madi.nekomath.com/P5/NetworkX.html', 'https://madi.nekomath.com/P5/BFS.html', 'https://madi.nekomath.com/P5/AplicacionesBFS.html', 'https://madi.nekomath.com/P5/DFS.html', 'https://madi.nekomath.com/P5/AplicacionesDFS.html', 'https://madi.nekomath.com/P5/ArbolPesoMin.html', 'https://madi.nekomath.com/P5/CaminosCortos.html', 'https://madi.nekomath.com/P5/RedesFlujos.html', 'https://madi.nekomath.com/P5/FordFulkerson.html', 'https://madi.nekomath.com/P5/GraficasNP.html']
# INFO:__main__:Procesando página: https://madi.nekomath.com/intro.html
# ERROR:__main__:Error en el proceso de conversión para pdfs/intro.pdf: Command '['xelatex', '-interaction=nonstopmode', 'pdfs/intro.tex']' returned non-zero exit status 1.
# ERROR:__main__:Salida estándar: This is XeTeX, Version 3.141592653-2.6-0.999996 (TeX Live 2024) (preloaded format=xelatex)
#  restricted \write18 enabled.
# entering extended mode
# (./pdfs/intro.tex
# LaTeX2e <2023-11-01> patch level 1
# L3 programming layer <2024-02-20>
# (/usr/local/texlive/2024/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2023/05/17 v1.4n Standard LaTeX document class
# (/usr/local/texlive/2024/texmf-dist/tex/latex/base/size10.clo))
# (/usr/local/texlive/2024/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/local/texlive/2024/texmf-dist/tex/latex/graphics-cfg/color.cfg)
# (/usr/local/texlive/2024/texmf-dist/tex/latex/graphics-def/xetex.def)
# (/usr/local/texlive/2024/texmf-dist/tex/latex/graphics/mathcolor.ltx))
# (/usr/local/texlive/2024/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/local/texlive/2024/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2024/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/local/texlive/2024/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/local/texlive/2024/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/local/texlive/2024/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/local/texlive/2024/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/local/texlive/2024/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/local/texlive/2024/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/local/texlive/2024/texmf-dist/tex/latex/amsfonts/amssymb.sty
# (/usr/local/texlive/2024/texmf-dist/tex/latex/amsfonts/amsfonts.sty))
# (/usr/local/texlive/2024/texmf-dist/tex/latex/unicode-math/unicode-math.sty
# (/usr/local/texlive/2024/texmf-dist/tex/latex/l3kernel/expl3.sty
# (/usr/local/texlive/2024/texmf-dist/tex/latex/l3backend/l3backend-xetex.def))
# (/usr/local/texlive/2024/texmf-dist/tex/latex/unicode-math/unicode-math-xetex.s
# ty (/usr/local/texlive/2024/texmf-dist/tex/latex/l3packages/xparse/xparse.sty)
# (/usr/local/texlive/2024/texmf-dist/tex/latex/l3packages/l3keys2e/l3keys2e.sty)
#  (/usr/local/texlive/2024/texmf-dist/tex/latex/fontspec/fontspec.sty
# (/usr/local/texlive/2024/texmf-dist/tex/latex/fontspec/fontspec-xetex.sty
# (/usr/local/texlive/2024/texmf-dist/tex/latex/base/fontenc.sty)
# (/usr/local/texlive/2024/texmf-dist/tex/latex/fontspec/fontspec.cfg)))
# (/usr/local/texlive/2024/texmf-dist/tex/latex/base/fix-cm.sty
# (/usr/local/texlive/2024/texmf-dist/tex/latex/base/ts1enc.def))
# (/usr/local/texlive/2024/texmf-dist/tex/latex/unicode-math/unicode-math-table.t
# ex))) (/usr/local/texlive/2024/texmf-dist/tex/latex/lm/lmodern.sty)
#
# ! Package fontspec Error: The font "DejaVu Serif" cannot be found.
#
# For immediate help type H <return>.
#  ...
#
# l.24     \setmonofont
#                      []{DejaVu Sans Mono}
# Missing character: There is no x ("78) in font nullfont!
# ! Use of \??? doesn't match its definition.
# <argument> \???
#                  ! LaTeX Error: Invalid operation fp_to_decimal(inf)
# l.24     \setmonofont
#                      []{DejaVu Sans Mono}
#
# ! Package fontspec Error: The font "DejaVu Serif" cannot be found.
#
# For immediate help type H <return>.
#  ...
#
# l.24     \setmonofont
#                      []{DejaVu Sans Mono}
#
# ! Package fontspec Error: The font "DejaVu Serif" cannot be found.
#
# For immediate help type H <return>.
#  ...
#
# l.24     \setmonofont
#                      []{DejaVu Sans Mono}
# Missing character: There is no x ("78) in font nullfont!
# ! Use of \??? doesn't match its definition.
# <argument> \???
#                  ! LaTeX Error: Invalid operation fp_to_decimal(inf)
# l.24     \setmonofont
#                      []{DejaVu Sans Mono}
# Missing character: There is no x ("78) in font nullfont!
# ! Use of \??? doesn't match its definition.
# <argument> \???
#                  ! LaTeX Error: Invalid operation fp_to_decimal(inf)
# l.24     \setmonofont
#                      []{DejaVu Sans Mono}
#
# ! Package fontspec Error: The font "DejaVu Serif" cannot be found.
#
# For immediate help type H <return>.
#  ...
#
# l.24     \setmonofont
#                      []{DejaVu Sans Mono}
# Missing character: There is no x ("78) in font nullfont!
# Missing character: There is no x ("78) in font nullfont!
# ! Use of \??? doesn't match its definition.
# <argument> \???
#                  ! LaTeX Error: Invalid operation (0)/(0)
# l.24     \setmonofont
#                      []{DejaVu Sans Mono}
# ! Use of \??? doesn't match its definition.
# <argument> \???
#                  ! LaTeX Error: Invalid operation fp_to_decimal(nan)
# l.24     \setmonofont
#                      []{DejaVu Sans Mono}
#
# ! Package fontspec Error: The font "DejaVu Serif" cannot be found.
#
# For immediate help type H <return>.
#  ...
#
# l.24     \setmonofont
#                      []{DejaVu Sans Mono}
#
# ! Package fontspec Error: The font "DejaVu Serif" cannot be found.
#
# For immediate help type H <return>.
#  ...
#
# l.24     \setmonofont
#                      []{DejaVu Sans Mono}
# Missing character: There is no x ("78) in font nullfont!
# Missing character: There is no x ("78) in font nullfont!
# ! Use of \??? doesn't match its definition.
# <argument> \???
#                  ! LaTeX Error: Invalid operation (0)/(0)
# l.24     \setmonofont
#                      []{DejaVu Sans Mono}
# ! Use of \??? doesn't match its definition.
# <argument> \???
#                  ! LaTeX Error: Invalid operation fp_to_decimal(nan)
# l.24     \setmonofont
#                      []{DejaVu Sans Mono}
# Missing character: There is no x ("78) in font nullfont!
# Missing character: There is no x ("78) in font nullfont!
# ! Use of \??? doesn't match its definition.
# <argument> \???
#                  ! LaTeX Error: Invalid operation (0)/(0)
# l.24     \setmonofont
#                      []{DejaVu Sans Mono}
# ! Use of \??? doesn't match its definition.
# <argument> \???
#                  ! LaTeX Error: Invalid operation fp_to_decimal(nan)
# l.24     \setmonofont
#                      []{DejaVu Sans Mono}
#
# ! Package fontspec Error: The font "DejaVu Sans Mono" cannot be found.
#
# For immediate help type H <return>.
#  ...
#
# l.25 \fi
#
# Missing character: There is no x ("78) in font nullfont!
# Missing character: There is no x ("78) in font nullfont!
# ! Use of \??? doesn't match its definition.
# <argument> \???
#                  ! LaTeX Error: Invalid operation (0)/(0)
# l.25 \fi
#
# ! Use of \??? doesn't match its definition.
# <argument> \???
#                  ! LaTeX Error: Invalid operation fp_to_decimal(nan)
# l.25 \fi
#
#
# ! Package fontspec Error: The font "DejaVu Sans Mono" cannot be found.
#
# For immediate help type H <return>.
#  ...
#
# l.25 \fi
#
#
# ! Package fontspec Error: The font "DejaVu Sans Mono" cannot be found.
#
# For immediate help type H <return>.
#  ...
#
# l.25 \fi
#
# Missing character: There is no x ("78) in font nullfont!
# Missing character: There is no x ("78) in font nullfont!
# ! Use of \??? doesn't match its definition.
# <argument> \???
#                  ! LaTeX Error: Invalid operation (0)/(0)
# l.25 \fi
#
# ! Use of \??? doesn't match its definition.
# <argument> \???
#                  ! LaTeX Error: Invalid operation fp_to_decimal(nan)
# l.25 \fi
#
# Missing character: There is no x ("78) in font nullfont!
# Missing character: There is no x ("78) in font nullfont!
# ! Use of \??? doesn't match its definition.
# <argument> \???
#                  ! LaTeX Error: Invalid operation (0)/(0)
# l.25 \fi
#
# ! Use of \??? doesn't match its definition.
# <argument> \???
#                  ! LaTeX Error: Invalid operation fp_to_decimal(nan)
# l.25 \fi
#
#
# ! Package fontspec Error: The font "DejaVu Sans Mono" cannot be found.
#
# For immediate help type H <return>.
#  ...
#
# l.25 \fi
#
# Missing character: There is no x ("78) in font nullfont!
# Missing character: There is no x ("78) in font nullfont!
# ! Use of \??? doesn't match its definition.
# <argument> \???
#                  ! LaTeX Error: Invalid operation (0)/(0)
# l.25 \fi
#
# ! Use of \??? doesn't match its definition.
# <argument> \???
#                  ! LaTeX Error: Invalid operation fp_to_decimal(nan)
# l.25 \fi
#
#
# ! Package fontspec Error: The font "DejaVu Sans Mono" cannot be found.
#
# For immediate help type H <return>.
#  ...
#
# l.25 \fi
#
#
# ! Package fontspec Error: The font "DejaVu Sans Mono" cannot be found.
#
# For immediate help type H <return>.
#  ...
#
# l.25 \fi
#
# Missing character: There is no x ("78) in font nullfont!
# Missing character: There is no x ("78) in font nullfont!
# ! Use of \??? doesn't match its definition.
# <argument> \???
#                  ! LaTeX Error: Invalid operation (0)/(0)
# l.25 \fi
#
# ! Use of \??? doesn't match its definition.
# <argument> \???
#                  ! LaTeX Error: Invalid operation fp_to_decimal(nan)
# l.25 \fi
#
# Missing character: There is no x ("78) in font nullfont!
# Missing character: There is no x ("78) in font nullfont!
# ! Use of \??? doesn't match its definition.
# <argument> \???
#                  ! LaTeX Error: Invalid operation (0)/(0)
# l.25 \fi
#
# ! Use of \??? doesn't match its definition.
# <argument> \???
#                  ! LaTeX Error: Invalid operation fp_to_decimal(nan)
# l.25 \fi
#
# (/usr/local/texlive/2024/texmf-dist/tex/latex/upquote/upquote.sty
# (/usr/local/texlive/2024/texmf-dist/tex/latex/base/textcomp.sty))
# (/usr/local/texlive/2024/texmf-dist/tex/latex/microtype/microtype.sty
# (/usr/local/texlive/2024/texmf-dist/tex/latex/etoolbox/etoolbox.sty)
# (/usr/local/texlive/2024/texmf-dist/tex/latex/microtype/microtype-xetex.def)
# (/usr/local/texlive/2024/texmf-dist/tex/latex/microtype/microtype.cfg))
# (/usr/local/texlive/2024/texmf-dist/tex/latex/parskip/parskip.sty
# (/usr/local/texlive/2024/texmf-dist/tex/latex/kvoptions/kvoptions.sty
# (/usr/local/texlive/2024/texmf-dist/tex/generic/ltxcmds/ltxcmds.sty)
# (/usr/local/texlive/2024/texmf-dist/tex/latex/kvsetkeys/kvsetkeys.sty)))
# (/usr/local/texlive/2024/texmf-dist/tex/generic/babel/babel.sty
# (/usr/local/texlive/2024/texmf-dist/tex/generic/babel/xebabel.def)
# (/usr/local/texlive/2024/texmf-dist/tex/generic/babel/nil.ldf))
# (/usr/local/texlive/2024/texmf-dist/tex/generic/babel/locale/es/babel-spanish.t
# ex)
#
# ! Package fontspec Error: The font "DejaVu Serif" cannot be found.
#
# For immediate help type H <return>.
#  ...
#
# l.50 \babelfont{rm}[]{DejaVu Serif}
#
# Missing character: There is no x ("78) in font nullfont!
# Missing character: There is no x ("78) in font nullfont!
# ! Use of \??? doesn't match its definition.
# <argument> \???
#                  ! LaTeX Error: Invalid operation (0)/(0)
# l.50 \babelfont{rm}[]{DejaVu Serif}
#
# ! Use of \??? doesn't match its definition.
# <argument> \???
#                  ! LaTeX Error: Invalid operation fp_to_decimal(nan)
# l.50 \babelfont{rm}[]{DejaVu Serif}
#
#
# ! Package fontspec Error: The font "DejaVu Serif" cannot be found.
#
# For immediate help type H <return>.
#  ...
#
# l.50 \babelfont{rm}[]{DejaVu Serif}
#
#
# ! Package fontspec Error: The font "DejaVu Serif" cannot be found.
#
# For immediate help type H <return>.
#  ...
#
# l.50 \babelfont{rm}[]{DejaVu Serif}
#
# Missing character: There is no x ("78) in font nullfont!
# Missing character: There is no x ("78) in font nullfont!
# ! Use of \??? doesn't match its definition.
# <argument> \???
#                  ! LaTeX Error: Invalid operation (0)/(0)
# l.50 \babelfont{rm}[]{DejaVu Serif}
#
# ! Use of \??? doesn't match its definition.
# <argument> \???
#                  ! LaTeX Error: Invalid operation fp_to_decimal(nan)
# l.50 \babelfont{rm}[]{DejaVu Serif}
#
# Missing character: There is no x ("78) in font nullfont!
# Missing character: There is no x ("78) in font nullfont!
# ! Use of \??? doesn't match its definition.
# <argument> \???
#                  ! LaTeX Error: Invalid operation (0)/(0)
# l.50 \babelfont{rm}[]{DejaVu Serif}
#
# ! Use of \??? doesn't match its definition.
# <argument> \???
#                  ! LaTeX Error: Invalid operation fp_to_decimal(nan)
# l.50 \babelfont{rm}[]{DejaVu Serif}
#
# ! Font TU/DejaVuSerif(2)/m/n/10="DejaVu Serif/OT" at 10.0pt not loadable: Metri
# c (TFM) file or installed font not found.
# <to be read again>
#                    relax
# l.50 \babelfont{rm}[]{DejaVu Serif}
#
# (/usr/local/texlive/2024/texmf-dist/tex/latex/bookmark/bookmark.sty
# (/usr/local/texlive/2024/texmf-dist/tex/latex/hyperref/hyperref.sty
# (/usr/local/texlive/2024/texmf-dist/tex/generic/kvdefinekeys/kvdefinekeys.sty)
# (/usr/local/texlive/2024/texmf-dist/tex/generic/pdfescape/pdfescape.sty
# (/usr/local/texlive/2024/texmf-dist/tex/generic/pdftexcmds/pdftexcmds.sty
# (/usr/local/texlive/2024/texmf-dist/tex/generic/infwarerr/infwarerr.sty)))
# (/usr/local/texlive/2024/texmf-dist/tex/latex/hycolor/hycolor.sty)
# (/usr/local/texlive/2024/texmf-dist/tex/latex/auxhook/auxhook.sty)
# (/usr/local/texlive/2024/texmf-dist/tex/latex/hyperref/nameref.sty
# (/usr/local/texlive/2024/texmf-dist/tex/latex/refcount/refcount.sty)
# (/usr/local/texlive/2024/texmf-dist/tex/generic/gettitlestring/gettitlestring.s
# ty)) (/usr/local/texlive/2024/texmf-dist/tex/latex/hyperref/pd1enc.def)
# (/usr/local/texlive/2024/texmf-dist/tex/generic/intcalc/intcalc.sty)
# (/usr/local/texlive/2024/texmf-dist/tex/latex/hyperref/puenc.def)
# (/usr/local/texlive/2024/texmf-dist/tex/latex/url/url.sty)
# (/usr/local/texlive/2024/texmf-dist/tex/generic/bitset/bitset.sty
# (/usr/local/texlive/2024/texmf-dist/tex/generic/bigintcalc/bigintcalc.sty))
# (/usr/local/texlive/2024/texmf-dist/tex/latex/base/atbegshi-ltx.sty))
# (/usr/local/texlive/2024/texmf-dist/tex/latex/hyperref/hxetex.def
# (/usr/local/texlive/2024/texmf-dist/tex/generic/stringenc/stringenc.sty)
# (/usr/local/texlive/2024/texmf-dist/tex/latex/rerunfilecheck/rerunfilecheck.sty
# (/usr/local/texlive/2024/texmf-dist/tex/latex/base/atveryend-ltx.sty)
# (/usr/local/texlive/2024/texmf-dist/tex/generic/uniquecounter/uniquecounter.sty
# ))) (/usr/local/texlive/2024/texmf-dist/tex/latex/bookmark/bkm-dvipdfm.def))
# (/usr/local/texlive/2024/texmf-dist/tex/latex/xurl/xurl.sty)
#
# ! Package fontspec Error: The font "DejaVu Serif" cannot be found.
#
# For immediate help type H <return>.
#  ...
#
# l.75         \setmonofont
#                          {DejaVu Sans Mono}
# Missing character: There is no x ("78) in font nullfont!
# Missing character: There is no x ("78) in font nullfont!
# ! Use of \??? doesn't match its definition.
# <argument> \???
#                  ! LaTeX Error: Invalid operation (0)/(0)
# l.75         \setmonofont
#                          {DejaVu Sans Mono}
# ! Use of \??? doesn't match its definition.
# <argument> \???
#                  ! LaTeX Error: Invalid operation fp_to_decimal(nan)
# l.75         \setmonofont
#                          {DejaVu Sans Mono}
#
# ! Package fontspec Error: The font "DejaVu Sans Mono" cannot be found.
#
# For immediate help type H <return>.
#  ...
#
# l.76         \usepackage
#                         {amsmath}
# Missing character: There is no x ("78) in font nullfont!
# Missing character: There is no x ("78) in font nullfont!
# ! Use of \??? doesn't match its definition.
# <argument> \???
#                  ! LaTeX Error: Invalid operation (0)/(0)
# l.76         \usepackage
#                         {amsmath}
# ! Use of \??? doesn't match its definition.
# <argument> \???
#                  ! LaTeX Error: Invalid operation fp_to_decimal(nan)
# l.76         \usepackage
#                         {amsmath}
# (/usr/local/texlive/2024/texmf-dist/tex/latex/graphics/graphicx.sty
# (/usr/local/texlive/2024/texmf-dist/tex/latex/graphics/graphics.sty
# (/usr/local/texlive/2024/texmf-dist/tex/latex/graphics/trig.sty)
# (/usr/local/texlive/2024/texmf-dist/tex/latex/graphics-cfg/graphics.cfg)))
#
# ! LaTeX Error: Option clash for package babel.
#
# See the LaTeX manual or LaTeX Companion for explanation.
# Type  H <return>  for immediate help.
#  ...
#
# l.81
#
# (./intro.aux
# ! Improper `at' size (0.0pt), replaced by 10pt.
# <to be read again>
#                    relax
# l.3 \@nameuse{bbl@beforestart}
#
# ! Font TU/DejaVuSansMono(0)/m/n/10="DejaVu Sans Mono" at 10.0pt not loadable: M
# etric (TFM) file or installed font not found.
# <to be read again>
#                    relax
# l.3 \@nameuse{bbl@beforestart}
#
#
# Package babel Info: The following font families will use the default
# (babel)             settings for all or some languages:
# (babel)             * \sffamily = lmss
# (babel)               "[lmsans10-regular]:mapping=tex-text;" at 10.0pt
# (babel)             * \ttfamily = DejaVuSansMono(0)
# (babel)               nullfont
# (babel)             There is nothing intrinsically wrong with it, but
# (babel)             'babel' will no set Script and Language, which could
# (babel)             be relevant in some languages. If your document uses
# (babel)             these families, consider redefining them with \babelfont.
# (babel)             Reported on input line 3.
#
#
# LaTeX Warning: Label `bienvenida' multiply defined.
#
# )
# *geometry* driver: auto-detecting
# *geometry* detected driver: xetex
# Missing character: There is no x ("78) in font nullfont!
# Missing character: There is no x ("78) in font nullfont!
# Missing character: There is no x ("78) in font nullfont!
# ! Improper `at' size (0.0pt), replaced by 10pt.
# <to be read again>
#                    relax
# l.82 \begin{document}
#
# Missing character: There is no x ("78) in font nullfont!
# Missing character: There is no x ("78) in font nullfont!
# Missing character: There is no x ("78) in font nullfont!
# Missing character: There is no x ("78) in font nullfont!
# Missing character: There is no x ("78) in font nullfont!
# ! Improper `at' size (0.0pt), replaced by 10pt.
# <to be read again>
#                    relax
# l.82 \begin{document}
#
# Missing character: There is no x ("78) in font nullfont!
# Missing character: There is no x ("78) in font nullfont!
# Missing character: There is no x ("78) in font nullfont!
# Missing character: There is no x ("78) in font nullfont!
# Missing character: There is no x ("78) in font nullfont!
# Missing character: There is no x ("78) in font nullfont!
# Missing character: There is no x ("78) in font nullfont!
# Missing character: There is no x ("78) in font nullfont!
# Missing character: There is no x ("78) in font nullfont!
# Missing character: There is no x ("78) in font nullfont!
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\`A'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\'A'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\^A'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\~A'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\"A'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\r A'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\k A'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\u A'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\`a'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\'a'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\^a'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\~a'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\"a'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\r a'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\k a'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\u a'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\'C'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\c C'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\v C'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\'c'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\c c'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\v c'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\v D'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\v d'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\`E'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\'E'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\^E'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\"E'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\k E'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\v E'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\`e'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\'e'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\^e'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\"e'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\k e'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\v e'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\u G'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\u g'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\`I'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\'I'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\^I'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\"I'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\.I'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\`i'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\'i'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\^i'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\"i'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\'L'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\v L'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\'l'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\v l'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\'N'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\~N'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\v N'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\'n'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\~n'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\v n'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\`O'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\'O'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\^O'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\~O'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\"O'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\H O'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\`o'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\'o'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\^o'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\~o'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\"o'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\H o'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\'R'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\v R'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\'r'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\v r'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\'S'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\c S'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\v S'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\'s'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\c s'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\v s'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\c T'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\v T'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\c t'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\v t'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\`U'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\'U'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\^U'
# (microtype)                in font encoding `TU' in inheritance list
# (microtype)                `microtype.cfg/411(protrusion)'.
#
#
# Package microtype Warning: Unknown slot number of character
# (microtype)                `\"U'
# ...
# Missing character: There is no a ("61) in font nullfont!
# Missing character: There is no l ("6C) in font nullfont!
# Missing character: There is no e ("65) in font nullfont!
# Missing character: There is no s ("73) in font nullfont!
# Missing character: There is no C ("43) in font nullfont!
# Missing character: There is no o ("6F) in font nullfont!
# Missing character: There is no n ("6E) in font nullfont!
# Missing character: There is no t ("74) in font nullfont!
# Missing character: There is no e ("65) in font nullfont!
# Missing character: There is no n ("6E) in font nullfont!
# Missing character: There is no i ("69) in font nullfont!
# Missing character: There is no d ("64) in font nullfont!
# Missing character: There is no o ("6F) in font nullfont!
# Missing character: There is no • ("2022) in font nullfont!
#
# LaTeX Warning: Hyper reference `introduccion' on page 3 undefined on input line
#  531.
#
# Missing character: There is no I ("49) in font nullfont!
# Missing character: There is no n ("6E) in font nullfont!
# Missing character: There is no t ("74) in font nullfont!
# Missing character: There is no r ("72) in font nullfont!
# Missing character: There is no o ("6F) in font nullfont!
# Missing character: There is no d ("64) in font nullfont!
# Missing character: There is no u ("75) in font nullfont!
# Missing character: There is no c ("63) in font nullfont!
# Missing character: There is no c ("63) in font nullfont!
# Missing character: There is no i ("69) in font nullfont!
# Missing character: There is no Ã ("C3) in font nullfont!
# Missing character: There is no ³ ("B3) in font nullfont!
# Missing character: There is no n ("6E) in font nullfont!
# Missing character: There is no • ("2022) in font nullfont!
#
# LaTeX Warning: Hyper reference `principio-de-las-casillas-version-basica' on pa
# ge 3 undefined on input line 534.
#
# Missing character: There is no P ("50) in font nullfont!
# Missing character: There is no r ("72) in font nullfont!
# Missing character: There is no i ("69) in font nullfont!
# Missing character: There is no n ("6E) in font nullfont!
# Missing character: There is no c ("63) in font nullfont!
# Missing character: There is no i ("69) in font nullfont!
# Missing character: There is no p ("70) in font nullfont!
# Missing character: There is no i ("69) in font nullfont!
# Missing character: There is no o ("6F) in font nullfont!
# Missing character: There is no d ("64) in font nullfont!
# Missing character: There is no e ("65) in font nullfont!
# Missing character: There is no l ("6C) in font nullfont!
# Missing character: There is no a ("61) in font nullfont!
# Missing character: There is no s ("73) in font nullfont!
# Missing character: There is no c ("63) in font nullfont!
# Missing character: There is no a ("61) in font nullfont!
# Missing character: There is no s ("73) in font nullfont!
# Missing character: There is no i ("69) in font nullfont!
# Missing character: There is no l ("6C) in font nullfont!
# Missing character: There is no l ("6C) in font nullfont!
# Missing character: There is no a ("61) in font nullfont!
# Missing character: There is no s ("73) in font nullfont!
# Missing character: There is no , ("2C) in font nullfont!
# Missing character: There is no v ("76) in font nullfont!
# Missing character: There is no e ("65) in font nullfont!
# Missing character: There is no r ("72) in font nullfont!
# Missing character: There is no s ("73) in font nullfont!
# Missing character: There is no i ("69) in font nullfont!
# Missing character: There is no Ã ("C3) in font nullfont!
# Missing character: There is no ³ ("B3) in font nullfont!
# Missing character: There is no n ("6E) in font nullfont!
# Missing character: There is no b ("62) in font nullfont!
# Missing character: There is no Ã ("C3) in font nullfont!
# Missing character: There is no ¡ ("A1) in font nullfont!
# Missing character: There is no s ("73) in font nullfont!
# Missing character: There is no i ("69) in font nullfont!
# Missing character: There is no c ("63) in font nullfont!
# Missing character: There is no a ("61) in font nullfont!
# Missing character: There is no • ("2022) in font nullfont!
#
# LaTeX Warning: Hyper reference `principio-de-las-casillas-version-con-mas-objet
# os' on page 3 undefined on input line 537.
#
# Missing character: There is no P ("50) in font nullfont!
# Missing character: There is no r ("72) in font nullfont!
# Missing character: There is no i ("69) in font nullfont!
# Missing character: There is no n ("6E) in font nullfont!
# Missing character: There is no c ("63) in font nullfont!
# Missing character: There is no i ("69) in font nullfont!
# Missing character: There is no p ("70) in font nullfont!
# Missing character: There is no i ("69) in font nullfont!
# Missing character: There is no o ("6F) in font nullfont!
# Missing character: There is no d ("64) in font nullfont!
# Missing character: There is no e ("65) in font nullfont!
# Missing character: There is no l ("6C) in font nullfont!
# Missing character: There is no a ("61) in font nullfont!
# Missing character: There is no s ("73) in font nullfont!
# Missing character: There is no c ("63) in font nullfont!
# Missing character: There is no a ("61) in font nullfont!
# Missing character: There is no s ("73) in font nullfont!
# Missing character: There is no i ("69) in font nullfont!
# Missing character: There is no l ("6C) in font nullfont!
# Missing character: There is no l ("6C) in font nullfont!
# Missing character: There is no a ("61) in font nullfont!
# Missing character: There is no s ("73) in font nullfont!
# Missing character: There is no , ("2C) in font nullfont!
# Missing character: There is no v ("76) in font nullfont!
# Missing character: There is no e ("65) in font nullfont!
# Missing character: There is no r ("72) in font nullfont!
# Missing character: There is no s ("73) in font nullfont!
# Missing character: There is no i ("69) in font nullfont!
# Missing character: There is no Ã ("C3) in font nullfont!
# Missing character: There is no ³ ("B3) in font nullfont!
# Missing character: There is no n ("6E) in font nullfont!
# Missing character: There is no c ("63) in font nullfont!
# Missing character: There is no o ("6F) in font nullfont!
# Missing character: There is no n ("6E) in font nullfont!
# Missing character: There is no m ("6D) in font nullfont!
# Missing character: There is no Ã ("C3) in font nullfont!
# Missing character: There is no ¡ ("A1) in font nullfont!
# Missing character: There is no s ("73) in font nullfont!
# Missing character: There is no o ("6F) in font nullfont!
# Missing character: There is no b ("62) in font nullfont!
# Missing character: There is no j ("6A) in font nullfont!
# Missing character: There is no e ("65) in font nullfont!
# Missing character: There is no t ("74) in font nullfont!
# Missing character: There is no o ("6F) in font nullfont!
# Missing character: There is no s ("73) in font nullfont!
# Missing character: There is no • ("2022) in font nullfont!
#
# LaTeX Warning: Hyper reference `principio-de-las-casillas-version-infinita' on
# page 3 undefined on input line 540.
#
# Missing character: There is no P ("50) in font nullfont!
# Missing character: There is no r ("72) in font nullfont!
# Missing character: There is no i ("69) in font nullfont!
# Missing character: There is no n ("6E) in font nullfont!
# Missing character: There is no c ("63) in font nullfont!
# Missing character: There is no i ("69) in font nullfont!
# Missing character: There is no p ("70) in font nullfont!
# Missing character: There is no i ("69) in font nullfont!
# Missing character: There is no o ("6F) in font nullfont!
# Missing character: There is no d ("64) in font nullfont!
# Missing character: There is no e ("65) in font nullfont!
# Missing character: There is no l ("6C) in font nullfont!
# Missing character: There is no a ("61) in font nullfont!
# Missing character: There is no s ("73) in font nullfont!
# Missing character: There is no c ("63) in font nullfont!
# Missing character: There is no a ("61) in font nullfont!
# Missing character: There is no s ("73) in font nullfont!
# Missing character: There is no i ("69) in font nullfont!
# Missing character: There is no l ("6C) in font nullfont!
# Missing character: There is no l ("6C) in font nullfont!
# Missing character: There is no a ("61) in font nullfont!
# Missing character: There is no s ("73) in font nullfont!
# Missing character: There is no , ("2C) in font nullfont!
# Missing character: There is no v ("76) in font nullfont!
# Missing character: There is no e ("65) in font nullfont!
# Missing character: There is no r ("72) in font nullfont!
# Missing character: There is no s ("73) in font nullfont!
# Missing character: There is no i ("69) in font nullfont!
# Missing character: There is no Ã ("C3) in font nullfont!
# Missing character: There is no ³ ("B3) in font nullfont!
# Missing character: There is no n ("6E) in font nullfont!
# Missing character: There is no i ("69) in font nullfont!
# Missing character: There is no n ("6E) in font nullfont!
# Missing character: There is no f ("66) in font nullfont!
# Missing character: There is no i ("69) in font nullfont!
# Missing character: There is no n ("6E) in font nullfont!
# Missing character: There is no i ("69) in font nullfont!
# Missing character: There is no t ("74) in font nullfont!
# Missing character: There is no a ("61) in font nullfont!
# Missing character: There is no • ("2022) in font nullfont!
#
# LaTeX Warning: Hyper reference `tarea-moral' on page 3 undefined on input line
# 542.
#
# Missing character: There is no T ("54) in font nullfont!
# Missing character: There is no a ("61) in font nullfont!
# Missing character: There is no r ("72) in font nullfont!
# Missing character: There is no e ("65) in font nullfont!
# Missing character: There is no a ("61) in font nullfont!
# Missing character: There is no m ("6D) in font nullfont!
# Missing character: There is no o ("6F) in font nullfont!
# Missing character: There is no r ("72) in font nullfont!
# Missing character: There is no a ("61) in font nullfont!
# Missing character: There is no l ("6C) in font nullfont!
# Missing character: There is no P ("50) in font nullfont!
# Missing character: There is no o ("6F) in font nullfont!
# Missing character: There is no r ("72) in font nullfont!
# Missing character: There is no L ("4C) in font nullfont!
# Missing character: There is no e ("65) in font nullfont!
# Missing character: There is no o ("6F) in font nullfont!
# Missing character: There is no n ("6E) in font nullfont!
# Missing character: There is no a ("61) in font nullfont!
# Missing character: There is no r ("72) in font nullfont!
# Missing character: There is no d ("64) in font nullfont!
# Missing character: There is no o ("6F) in font nullfont!
# Missing character: There is no I ("49) in font nullfont!
# Missing character: There is no g ("67) in font nullfont!
# Missing character: There is no n ("6E) in font nullfont!
# Missing character: There is no a ("61) in font nullfont!
# Missing character: There is no c ("63) in font nullfont!
# Missing character: There is no i ("69) in font nullfont!
# Missing character: There is no o ("6F) in font nullfont!
# Missing character: There is no M ("4D) in font nullfont!
# Missing character: There is no a ("61) in font nullfont!
# Missing character: There is no r ("72) in font nullfont!
# Missing character: There is no t ("74) in font nullfont!
# Missing character: There is no Ã ("C3) in font nullfont!
# Missing character: There is no - ("2D) in font nullfont!
# Missing character: There is no n ("6E) in font nullfont!
# Missing character: There is no e ("65) in font nullfont!
# Missing character: There is no z ("7A) in font nullfont!
# Missing character: There is no S ("53) in font nullfont!
# Missing character: There is no a ("61) in font nullfont!
# Missing character: There is no n ("6E) in font nullfont!
# Missing character: There is no d ("64) in font nullfont!
# Missing character: There is no o ("6F) in font nullfont!
# Missing character: There is no v ("76) in font nullfont!
# Missing character: There is no a ("61) in font nullfont!
# Missing character: There is no l ("6C) in font nullfont!
# Missing character: There is no Â ("C2) in font nullfont!
# Missing character: There is no © ("A9) in font nullfont!
# Missing character: There is no C ("43) in font nullfont!
# Missing character: There is no o ("6F) in font nullfont!
# Missing character: There is no p ("70) in font nullfont!
# Missing character: There is no y ("79) in font nullfont!
# Missing character: There is no r ("72) in font nullfont!
# Missing character: There is no i ("69) in font nullfont!
# Missing character: There is no g ("67) in font nullfont!
# Missing character: There is no h ("68) in font nullfont!
# Missing character: There is no t ("74) in font nullfont!
# Missing character: There is no 2 ("32) in font nullfont!
# Missing character: There is no 0 ("30) in font nullfont!
# Missing character: There is no 2 ("32) in font nullfont!
# Missing character: There is no 2 ("32) in font nullfont!
# Missing character: There is no . ("2E) in font nullfont!
#
# Underfull \hbox (badness 10000) in paragraph at lines 547--548
#
# Missing character: There is no 3 ("33) in font nullfont!
# [3] (./Casillas.aux)
#
# LaTeX Font Warning: Some font shapes were not available, defaults substituted.
#
#
# LaTeX Warning: There were undefined references.
#
#
# LaTeX Warning: Label(s) may have changed. Rerun to get cross-references right.
#
#  )
# (see the transcript file for additional information)
# Output written on Casillas.pdf (3 pages).
# Transcript written on Casillas.log.
#
# ERROR:__main__:Salida de error:
# INFO:__main__:Procesando página: https://madi.nekomath.com/P1/DobleConteo.html
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 105
#     102 logger.info(f"Procesando página: {page_url}")
#     104 pdf_filename = f"pdfs/{os.path.basename(page_url).replace('.html', '.pdf')}"
# --> 105 if html_to_pdf(page_url, pdf_filename):
#     106     successful_pdfs.append(pdf_filename)
#     108 time.sleep(1)  # Esperar 1 segundo entre solicitudes
#
# Cell In[24], line 68, in html_to_pdf(url, output_filename)
#      66 xelatex_command = ['xelatex', '-interaction=nonstopmode', latex_filename]
#      67 for _ in range(2):  # Ejecutar dos veces para resolver referencias
# ---> 68     result = subprocess.run(xelatex_command, check=True, capture_output=True, text=True)
#      70 logger.info(f"PDF creado con éxito: {output_filename}")
#      72 # Limpiar archivos temporales
#
# File /opt/homebrew/anaconda3/envs/dataScience/lib/python3.12/subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File /opt/homebrew/anaconda3/envs/dataScience/lib/python3.12/subprocess.py:1209, in Popen.communicate(self, input, timeout)
#    1206     endtime = None
#    1208 try:
# -> 1209     stdout, stderr = self._communicate(input, endtime, timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # See the detailed comment in .wait().
#    1213     if timeout is not None:
#
# File /opt/homebrew/anaconda3/envs/dataScience/lib/python3.12/subprocess.py:2115, in Popen._communicate(self, input, endtime, orig_timeout)
#    2108     self._check_timeout(endtime, orig_timeout,
#    2109                         stdout, stderr,
#    2110                         skip_check_and_raise=True)
#    2111     raise RuntimeError(  # Impossible :)
#    2112         '_check_timeout(..., skip_check_and_raise=True) '
#    2113         'failed to raise TimeoutExpired.')
# -> 2115 ready = selector.select(timeout)
#    2116 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2118 # XXX Rewrite these to use non-blocking I/O on the file
#    2119 # objects; they are no longer using C stdio!
#
# File /opt/homebrew/anaconda3/envs/dataScience/lib/python3.12/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:
